# %%
import os
import sys

print(os.getcwd())
# Out:
# c:\Users\yifan\Documents\Uni\COMP9491\repo\COMP9491\src\EDA

# %%
ROOT_DIR = os.path.realpath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(ROOT_DIR)
print(ROOT_DIR)
# Out:
# C:\Users\yifan\Documents\Uni\COMP9491\repo\COMP9491

# %%
import pandas as pd 

jobs = pd.read_csv(os.path.join(ROOT_DIR, "data", "job_postings_dev.csv"))

# %%
jobs
# Out:
#         job_id  company_id                                            title  \
# 0   3693047788  11294318.0                               Project Accountant
# 1   3693047822     11056.0                                 Staff Accountant
# 2   3693048156     77499.0                                 Staff Accountant
# 3   3693048189   2913934.0                                 Staff Accountant
# 4   3693048246    146857.0                          Senior Staff Accountant
# 5   3693048365      8117.0                                       Accountant
# 6   3693048644     59226.0                            Senior Tax Accountant
# 7   3693048860         NaN                                 Staff Accountant
# 8   3693049374    917557.0                                 Staff Accountant
# 9   3693049632   2762306.0                                Senior Accountant
# 10  3693049662   2913934.0                                 Staff Accountant
# ...

# %%
jobs.groupby("title")["job_id"].count().sort_values(ascending=False)[0:20]
# Out:
# title
# Sales Director [Owner/Operator]                         83
# Sales Associate                                         64
# Retail Sales Associate                                  60
# Sales Director {Owner/Operator}                         54
# Project Manager                                         40
# Administrative Assistant                                40
# Staff Accountant                                        40
# Customer Service Representative                         39
# Call Center Support Rep                                 38
# Senior Accountant                                       37
# Executive Assistant                                     37
# Scoring Content Specialist                              36
# Account Executive                                       34
# Sales Manager                                           34
# General Superintendent, Mission Critical - Traveling    29
# Block Advisor - Remote Tax Professional                 29
# ...

# %%
jobs.groupby("title")["job_id"].count().sort_values(ascending=False).shape[0]
# Out:
# 10956

# %%
jobs["words_in_title"] = jobs["title"].apply(lambda x: len(x.split(" ")))

# %%
jobs[jobs["words_in_title"]<=2]
# Out:
#            job_id  company_id                  title  \
# 1       133114754  77766802.0          Sales Manager
# 3       381055942  96654609.0       Business Manager
# 5       903408693   3894635.0       Office Associate
# 6       967848246  18995316.0      Education Manager
# 7      1004740969    882349.0         Civil Engineer
# ...           ...         ...                    ...
# 15875  3701373427   1321042.0          Design Intern
# 15880  3701373515  74718032.0  Sanitation Technician
# 15881  3701373516  74718032.0  Sanitation Technician
# 15882  3701373522     38897.0         Unit Secretary
# 15884  3701373524      2623.0            MRI Manager
#
#                                              description  max_salary  \
# 1      Are you a dynamic and creative marketing profe...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# 5      Provide clerical and administrative support to...    42000.00
# ...

# %%
jobs.groupby("formatted_experience_level").count()
# Out:
#                             job_id  company_id  title  description  \
# formatted_experience_level
# Associate                     1220        1209   1220         1220
# Director                       687         684    687          687
# Entry level                   3694        3694   3694         3694
# Executive                      134         130    134          134
# Internship                     166         166    166          166
# Mid-Senior level              5083        5064   5083         5083
#
#                             max_salary  med_salary  min_salary  pay_period  \
# formatted_experience_level
# Associate                          588          34         588         622
# Director                           224          73         224         297
# Entry level                       1048         335        1048        1383
# Executive                           49          16          49          65
# ...

# %%
jobs.columns
# Out:
# Index(['job_id', 'company_id', 'title', 'description', 'max_salary',
#        'med_salary', 'min_salary', 'pay_period', 'formatted_work_type',
#        'location', 'applies', 'original_listed_time', 'remote_allowed',
#        'views', 'job_posting_url', 'application_url', 'application_type',
#        'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type', 'words_in_title'],
#       dtype='object')

# %%
jobs["skills_desc"].dropna().reset_index(drop=True)
# Out:
# 0      EducationBachelors or better in Education or r...
# 1      \n\nMinimum Requirements Required Knowledge an...
# 2                          EducationDoctorate or better.
# 3      \n\nMust Have: Minimum Requirements \n\nTo be ...
# 4                              C++,Networking,Gaming,MMO
#                              ...
# 139    \nBachelor's degree in Sales, Business, Market...
# 140    Bachelor's degree in business or related field...
# 141    \n\nInstallation Technician Job RequirementsMu...
# 142    ASIC/FPGA,VHDL/Verilog,Digital circuit archite...
# 143    EDUCATION AND EXPERIENCE• Bachelor's degree in...
# Name: skills_desc, Length: 144, dtype: object

# %%
job_filtered = jobs[jobs["formatted_experience_level"]=="Mid-Senior level"]
job_filtered[job_filtered[""]]
# Out:
#            job_id  company_id  \
# 20     2148434137    601919.0
# 21     2148434265  34218836.0
# 23     2148434586   2780388.0
# 24     2148434616     15564.0
# 29     2148434909   6600327.0
# ...           ...         ...
# 15875  3701373427   1321042.0
# 15876  3701373432   2121817.0
# 15878  3701373493      5619.0
# 15879  3701373514  74718032.0
# 15884  3701373524      2623.0
#
#                                                    title  \
# 20         Customer Success & Services Marketing Manager
# 21     Locum Critical Care Physician Assistant job in...
# 23                          Manager, Salesforce Platform
# 24     Lead Solar Maintenance Roofer, Residential Ser...
# 29                  Clinic Managers - Physical Therapist
# ...                                                  ...
# 15875                                      Design Intern
# 15876                  Continuous Improvement Specialist
# 15878         Sr. Bilingual Copywriter (Canadian French)
# ...

# %%
jobs
# Out:
#            job_id  company_id                                  title  \
# 0        85008768         NaN               Licensed Insurance Agent
# 1       133114754  77766802.0                          Sales Manager
# 2       133196985   1089558.0                     Model Risk Auditor
# 3       381055942  96654609.0                       Business Manager
# 4       529257371   1244539.0                    NY Studio Assistant
# ...           ...         ...                                    ...
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# ...
